# %%
import pandas as pd

# %%
#import raw csv file
raw_df = pd.read_csv('C:\Users\Work\Documents\Data Stuff\Springboard course\data-tool-export.csv')
raw_df.head(70)
# Out:
#                                  City  \
# 0                            Aberdeen
# 1                           Aldershot
# 2                            Barnsley
# 3                            Basildon
# 4                             Belfast
# 5                          Birkenhead
# 6                          Birmingham
# 7                           Blackburn
# 8                           Blackpool
# 9                         Bournemouth
# 10                           Bradford
# 11                           Brighton
# 12                            Bristol
# 13                            Burnley
# 14                          Cambridge
# 15                            Cardiff
# 16                            Chatham
# 17                           Coventry
# 18                            Crawley
# 19                              Derby
# 20                          Doncaster
# 21                             Dundee
# 22                          Edinburgh
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Columns: 409 entries, City to Unnamed: 408
# dtypes: float64(221), object(188)
# memory usage: 389.9+ KB

# %%
raw_df.columns
# Out:
# Index([u'City', u'Average Weekly Workplace Earnings 2004  (£)',
#        u'Average Weekly Workplace Earnings 2005  (£)',
#        u'Average Weekly Workplace Earnings 2006  (£)',
#        u'Average Weekly Workplace Earnings 2007  (£)',
#        u'Average Weekly Workplace Earnings 2008  (£)',
#        u'Average Weekly Workplace Earnings 2009  (£)',
#        u'Average Weekly Workplace Earnings 2010  (£)',
#        u'Average Weekly Workplace Earnings 2011  (£)',
#        u'Average Weekly Workplace Earnings 2012  (£)',
#        ...
#        u'Youth Claimant Count Sep 2016  (%)',
#        u'Youth Claimant Count Oct 2016  (%)',
#        u'Youth Claimant Count Nov 2016  (%)',
#        u'Youth Claimant Count Dec 2016  (%)',
#        u'Youth Claimant Count Jan 2017  (%)',
#        u'Youth Claimant Count Feb 2017  (%)',
#        u'Youth Claimant Count Mar 2017  (%)',
#        u'Youth Claimant Count Apr 2017  (%)',
#        u'Youth Claimant Count May 2017  (%)', u'Unnamed: 408'],
# ...

# %%
#remove footer lines and preserve data only
raw_df = raw_df.iloc[0:63]
raw_df.tail()
# Out:
#           City Average Weekly Workplace Earnings 2004  (£)  \
# 58   Wakefield                                  482.745098
# 59  Warrington                                 540.2614379
# 60       Wigan                                 452.1568627
# 61    Worthing                                 481.9607843
# 62        York                                 498.9542484
#
#    Average Weekly Workplace Earnings 2005  (£)  \
# 58                                 493.2051282
# 59                                 546.5384615
# 60                                 465.3846154
# 61                                 481.9230769
# 62                                 479.6153846
#
#    Average Weekly Workplace Earnings 2006  (£)  \
# 58                                 505.2631579
# 59                                 510.7769424
# 60                                 474.6867168
# 61                                 484.5864662
# 62                                 500.2506266
#
# ...

# %%
# set City as index column and convert data to numeric
raw_df_1 = raw_df.set_index('City')

raw_df_1 = raw_df_1.convert_objects(convert_numeric=True)
raw_df_1.head()
# Out:
# C:\Users\Work\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
#            Average Weekly Workplace Earnings 2004  (£)  \
# City
# Aberdeen                                    588.758170
# Aldershot                                   710.333677
# Barnsley                                    484.967320
# Basildon                                    601.960784
# Belfast                                            NaN
#
#            Average Weekly Workplace Earnings 2005  (£)  \
# City
# Aberdeen                                    594.615385
# Aldershot                                   675.395560
# Barnsley                                    483.333333
# Basildon                                    600.128205
# Belfast                                            NaN
#
# ...

# %%
raw_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, Aberdeen to York
# Columns: 408 entries, Average Weekly Workplace Earnings 2004  (£) to Unnamed: 408
# dtypes: float64(400), object(8)
# memory usage: 201.3+ KB

# %%
# drop final column which was imported by error and contains no data
raw_df_1 = raw_df_1.drop('Unnamed: 408', axis=1)

# %%
raw_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, Aberdeen to York
# Columns: 407 entries, Average Weekly Workplace Earnings 2004  (£) to Youth Claimant Count May 2017  (%)
# dtypes: float64(399), object(8)
# memory usage: 200.8+ KB

# %%
raw_df_1.select_dtypes(include=[object])
# Out:
#               Mean house price  1995  (£) Mean house price  1996  (£)  \
# City
# Aberdeen
# Aldershot
# Barnsley
# Basildon
# Belfast
# Birkenhead
# Birmingham
# Blackburn
# Blackpool
# Bournemouth
# Bradford
# Brighton
# Bristol
# Burnley
# Cambridge
# Cardiff
# Chatham
# Coventry
# Crawley
# Derby
# Doncaster
# Dundee
# Edinburgh
# Exeter
# Glasgow
# Gloucester
# Huddersfield
# Hull
# Ipswich
# Leeds
# ...                                   ...                         ...
# Luton
# Manchester
# Mansfield
# Middlesbrough
# Milton Keynes
# Newcastle
# Newport
# Northampton
# Norwich
# Nottingham
# Oxford
# Peterborough
# Plymouth
# Portsmouth
# Preston
# Reading
# Sheffield
# Slough
# Southampton
# Southend
# Stoke
# Sunderland
# Swansea
# Swindon
# Telford
# Wakefield
# Warrington
# Wigan
# Worthing
# York
#
#               Mean house price  1997  (£) Mean house price  1998  (£)  \
# City
# Aberdeen
# Aldershot
# Barnsley
# Basildon
# Belfast
# Birkenhead
# Birmingham
# Blackburn
# ...

# %%
# remove 8 object type columns as they contain no data
# final data frame contains only columns of type float and is clean for data analysis
raw_df_2 = raw_df_1.select_dtypes(exclude=[object])
raw_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, Aberdeen to York
# Columns: 399 entries, Average Weekly Workplace Earnings 2004  (£) to Youth Claimant Count May 2017  (%)
# dtypes: float64(399)
# memory usage: 196.9+ KB
